# %%
import os
from dotenv import load_dotenv
load_dotenv()
import asyncio

from codecs import StreamReader
from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.ui import Console

api_key = os.getenv("OPEN_ROUTER_API_KEY") 

model_client = OpenAIChatCompletionClient(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
    model="openai/gpt-4o-mini",    
    model_info={
        "family": "openai",
        "vision": False,
        "function_calling": True,
        "json_output": True,
        "structured_output": True
    },
)

# %%
assistant = AssistantAgent(
    name="Assistant",
    model_client = model_client,
    system_message="You are a helpful assistant.",
)

user_proxy_agent = UserProxyAgent(
    name="UserProxy",
    description="You are a user proxy.",
    input_func = input
)

termination_condition = TextMentionTermination(text='APPROVE')

team = RoundRobinGroupChat(
    participants=[assistant, user_proxy_agent],
    termination_condition=termination_condition,
    max_turns=10
)

stream = team.run_stream(task="Write a great poem about India?")

await Console(stream)
# Out:
# ---------- TextMessage (user) ----------
# Write a great poem about India?
# ---------- TextMessage (Assistant) ----------
# **Ode to India**
#
# In the heart of the world, where the rivers weave,
# A tapestry of cultures, in harmony, we believe.
# From the Himalayas' peaks, where the snowflakes kiss,
# To the shores of the ocean, where the waves whisper bliss.
#
# Colors swirl in the markets, vibrant and bright,
# Saffron and turmeric, a feast for the sight.
# The hum of the city, the calm of the field,
# In every corner, a story concealed.
#
# The scent of cardamom wafts through the air,
# As laughter and music fill moments we share.
# From ancient texts that echo wisdom’s decree,
# To the rhythms of life in each bustling bazaar spree.
#
# Ganges flows sacred, its waters divine,
# A lifeline of faith, where the spirits align.
# Mysore's silk saris and Rajasthani forts,
# Echo through ages, in history, they sport.
#
# Unity in diversity, a mosaic so grand,
# Where a thousand tongues meet, hand in hand.
# In festivals' glow, under lanterns aglow,
# We dance through the ages, letting our spirits flow.
#
# Oh, India, home of the brave and the wise,
# In your vast embrace, every soul can arise.
# From the echoes of freedom in the air we breathe,
# To the dreams of tomorrow that we dare to weave.
#
# So here’s to your essence, rich and profound,
# In every heartbeat, your magic is found.
# A land of enchantment, of struggle and grace,
# In the soul of the world, you hold a sacred place.
# ---------- TextMessage (UserProxy) ----------
# make it easy to read
# ---------- TextMessage (Assistant) ----------
# **Ode to India**
#
# In the heart of the world, where rivers flow,
# A mix of cultures, in unity we grow.
# From the Himalayas, where the snowflakes kiss,
# To ocean shores, where waves bring bliss.
#
# Markets filled with colors, bright and bold,
# Saffron and turmeric, stories unfold.
# The city hums, the fields are calm,
# In every corner, a tale, a charm.
#
# The scent of cardamom fills the air,
# Laughter and music, moments we share.
# From ancient wisdom in sacred texts,
# To lively bazaars, each day perplexed.
#
# The Ganges flows, holy and clear,
# A lifeline of faith, where spirits draw near.
# Mysore’s silk and Rajasthani forts,
# Whispering history, rich, untold sorts.
#
# Unity in diversity, a beautiful blend,
# With a thousand voices, hand in hand we stand.
# In festivals' glow, under lanterns bright,
# We dance through ages, hearts full of light.
#
# Oh, India, land of the brave and wise,
# In your embrace, every dream can rise.
# From echoes of freedom in the air we breathe,
# To tomorrow's hopes that we dare to weave.
#
# So here’s to your spirit, rich and deep,
# In every heartbeat, your magic we keep.
# A land full of wonder, of struggle and grace,
# In the heart of the world, you hold a special place.
# ---------- TextMessage (UserProxy) ----------
# make it just 10 words
# ---------- TextMessage (Assistant) ----------
# Diverse cultures thrive, ancient wisdom flows, India’s spirit shines bright.
# ---------- TextMessage (UserProxy) ----------
# APPROVE
# TaskResult(messages=[TextMessage(id='46602cca-cd16-4e63-8bdf-f2f5d4f4656a', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 15, 11, 49, 20, 861625, tzinfo=datetime.timezone.utc), content='Write a great poem about India?', type='TextMessage'), TextMessage(id='1471327d-47ea-4070-84f2-47a6713598d5', source='Assistant', models_usage=RequestUsage(prompt_tokens=25, completion_tokens=340), metadata={}, created_at=datetime.datetime(2026, 2, 15, 11, 49, 28, 213362, tzinfo=datetime.timezone.utc), content="**Ode to India**\n\nIn the heart of the world, where the rivers weave,  \nA tapestry of cultures, in harmony, we believe.  \nFrom the Himalayas' peaks, where the snowflakes kiss,  \nTo the shores of the ocean, where the waves whisper bliss.  \n\nColors swirl in the markets, vibrant and bright,  \nSaffron and turmeric, a feast for the sight.  \nThe hum of the city, the calm of the field,  \nIn every corner, a story concealed.  \n\nThe scent of cardamom wafts through the air,  \nAs laughter and music fill moments we share.  \nFrom ancient texts that echo wisdom’s decree,  \nTo the rhythms of life in each bustling bazaar spree.  \n\nGanges flows sacred, its waters divine,  \nA lifeline of faith, where the spirits align.  \nMysore's silk saris and Rajasthani forts,  \nEcho through ages, in history, they sport.  \n\nUnity in diversity, a mosaic so grand,  \nWhere a thousand tongues meet, hand in hand.  \nIn festivals' glow, under lanterns aglow,  \nWe dance through the ages, letting our spirits flow.  \n\nOh, India, home of the brave and the wise,  \nIn your vast embrace, every soul can arise.  \nFrom the echoes of freedom in the air we breathe,  \nTo the dreams of tomorrow that we dare to weave.  \n\nSo here’s to your essence, rich and profound,  \nIn every heartbeat, your magic is found.  \nA land of enchantment, of struggle and grace,  \nIn the soul of the world, you hold a sacred place.  ", type='TextMessage'), UserInputRequestedEvent(id='7a2eca02-5acd-4482-85a7-9ff13e1e4995', source='UserProxy', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 15, 11, 49, 28, 217175, tzinfo=datetime.timezone.utc), request_id='b4219a4f-3198-4856-81b5-4830bbbc1494', content='', type='UserInputRequestedEvent'), TextMessage(id='c6fa9dd4-19aa-4737-9dc5-66feaa907c4a', source='UserProxy', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 15, 11, 49, 36, 815221, tzinfo=datetime.timezone.utc), content='make it easy to read', type='TextMessage'), TextMessage(id='f2711df5-2d87-43ed-8759-9f3f6cd3a07a', source='Assistant', models_usage=RequestUsage(prompt_tokens=381, completion_tokens=315), metadata={}, created_at=datetime.datetime(2026, 2, 15, 11, 49, 42, 701364, tzinfo=datetime.timezone.utc), content="**Ode to India**\n\nIn the heart of the world, where rivers flow,  \nA mix of cultures, in unity we grow.  \nFrom the Himalayas, where the snowflakes kiss,  \nTo ocean shores, where waves bring bliss.  \n\nMarkets filled with colors, bright and bold,  \nSaffron and turmeric, stories unfold.  \nThe city hums, the fields are calm,  \nIn every corner, a tale, a charm.  \n\nThe scent of cardamom fills the air,  \nLaughter and music, moments we share.  \nFrom ancient wisdom in sacred texts,  \nTo lively bazaars, each day perplexed.  \n\nThe Ganges flows, holy and clear,  \nA lifeline of faith, where spirits draw near.  \nMysore’s silk and Rajasthani forts,  \nWhispering history, rich, untold sorts.  \n\nUnity in diversity, a beautiful blend,  \nWith a thousand voices, hand in hand we stand.  \nIn festivals' glow, under lanterns bright,  \nWe dance through ages, hearts full of light.  \n\nOh, India, land of the brave and wise,  \nIn your embrace, every dream can rise.  \nFrom echoes of freedom in the air we breathe,  \nTo tomorrow's hopes that we dare to weave.  \n\nSo here’s to your spirit, rich and deep,  \nIn every heartbeat, your magic we keep.  \nA land full of wonder, of struggle and grace ...
