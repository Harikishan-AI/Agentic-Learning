# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import GroqChatCompletionClient
from dotenv import load_dotenv
load_dotenv()
import os
api_key = os.getenv("GROQ_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from autogen_agentchat.agents import AssistantAgent
# ----> 2 from autogen_ext.models.openai import GroqChatCompletionClient
#       3 from dotenv import load_dotenv
#       4 load_dotenv()
#
# ImportError: cannot import name 'GroqChatCompletionClient' from 'autogen_ext.models.openai' (e:\projects\agentic\.venv\Lib\site-packages\autogen_ext\models\openai\__init__.py)

# %%
model_client = GroqChatCompletionClient(
    model="openai/gpt-oss-120b",
    api_key=os.getenv("OPENAI_API_KEY"),
)
