# %%
import asyncio
import os
from autogen_agentchat.agents import AssistantAgent
from autogen_core.memory import MemoryContent, MemoryMimeType
from autogen_ext.memory.mem0 import Mem0Memory
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPEN_ROUTER_API_KEY") 

model_client = OpenAIChatCompletionClient(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
    model="qwen/qwen3-vl-30b-a3b-thinking",    
    model_info={
        "family": "qwen",
        "vision": False,
        "function_calling": True,
        "json_output": True,
        "structured_output": True
    },
)

# %%
mem0_memory = Mem0Memory(
        user_id='user12345',
        is_cloud=True,
        api_key=os.getenv("MEM0_API_KEY")
        )
try:
    print("Attempting to add memories to cloud")

    messages = [
        {
            "role":'user',"content": "I am a vegetarian food and I love cooking.",
        },
        {
            "role":'assistant',"content": "I will remember that preference is Vegetarian.",
        },
    ]

    mem0_memory._client.add(messages,user_id='user12345',metadata={"category": "preferences","type": "diet"})

    messages = [
        {
            "role":'user',"content": "I prefer weather information in metric units.",
        },
        {
            "role":'assistant',"content": "I will remember that  you prefer metric unit in weather.",
        },
    ]

    mem0_memory._client.add(messages,user_id='user12345',metadata={"category": "preferences","type": "units"})


    print("Memories added successfully")
except Exception as e:
    print(f"Error adding memories: {e}")
agent = AssistantAgent(
        name='assistant',
        model_client=model_client,
        memory=[mem0_memory],
        system_message="You are a helpful assistant that remembers user preferences and use them to provide personalized responses.")

try:
    result = await agent.run(task='what is the waether in delhi?')

    print('Agent Response:',result.messages[-1].content)
except Exception as e:
    print(f"Error running agent: {e}")
# Out:
# Attempting to add memories to cloud
# Memories added successfully
# Error querying mem0 memory: {"error":"Filters are required and cannot be empty. Please refer to https://docs.mem0.ai/api-reference/memory/search-memories"}
# Agent Response: The weather in Delhi varies significantly by season, but **as of today (October 2024)**, here's what you need to know:
#
# ### 🌤️ **Current Conditions** (Last Updated: October 15, 2024)
# - **Temperature**: 24°C to 32°C (75°F to 90°F)
# - **Conditions**: Clear skies with low humidity. *Note: Delhi often experiences sudden heatwaves even in post-monsoon season.*
# - **Air Quality**: **Moderate** (AQI 75-100). Pollution levels can rise in winter but are usually better in October.
# - **Monsoon**: **Over** (monsoon typically ends by mid-September).
#
# ### 🌍 **Seasonal Breakdown**
# | Season | Timeframe | Temperature | Key Features |
# |--------|-----------|-------------|--------------|
# | **Summer** | Apr–Jun | 35°C–45°C (95°F–113°F) | Extremely hot, dusty, and humid. |
# | **Monsoon** | Jul–Sep | 28°C–35°C (82°F–95°F) | Heavy rain, high humidity, occasional thunderstorms. |
# | **Autumn** | Oct–Nov | 20°C–32°C (68°F–90°F) | **Best time to visit!** Cool, dry, and clear skies. |
# | **Winter** | Dec–Feb | 5°C–20°C (41°F–68°F) | Cold mornings, foggy, *very* polluted. |
#
# ### 💡 **What to Expect Right Now**
# - **Today**: Sunny with minimal rain. Light jacket recommended for evenings.
# - **Upcoming Week**: Gradual cooling; temperatures may drop to 18°C (64°F) at night.
# - **Tip**: Delhi’s weather is **highly variable**—carry a light shawl for evenings and sunscreen for daytime.
#
# ### ⚠️ **Important Note**
# Delhi’s air quality can worsen rapidly in winter (Dec–Jan), but **October is generally pleasant**. If you’re traveling soon, check real-time updates via [India Meteorological Department](https://mausam.imd.gov.in/) or apps like *WeatherNow*.
#
# Let me know if you’d like **today’s detailed forecast** (I can pull live data) or advice for a specific date! 😊
