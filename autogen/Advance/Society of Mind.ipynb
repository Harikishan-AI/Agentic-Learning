# %%
print("\n🏗️  Society of Mind Architecture:")
print("""
    ┌─────────────────────────────────────-┐
    │        Society of Mind Agent         │
    │  ┌─────────────────────────────────┐ │
    │  │         Inner Team              │ │
    │  │  ┌─────────┐  ┌─────────────┐   │ │
    │  │  │ Agent A │  │   Agent B   │   │ │
    │  │  │(Writer) │  │  (Editor)   │   │ │
    │  │  └─────────┘  └─────────────┘   │ │
    │  │         │            │          │ │
    │  │         └────┬───────┘          │ │
    │  │              │                  │ │
    │  │         Discussion              │ │
    │  └─────────────────────────────────┘ │
    │                 │                    │
    │            Synthesis                 │
    │                 │                    │
    │           Final Response             │
    └─────────────────────────────────────-┘
    """)
# Out:
# 🏗️  Society of Mind Architecture:
#
#     ┌─────────────────────────────────────-┐
#     │        Society of Mind Agent         │
#     │  ┌─────────────────────────────────┐ │
#     │  │         Inner Team              │ │
#     │  │  ┌─────────┐  ┌─────────────┐   │ │
#     │  │  │ Agent A │  │   Agent B   │   │ │
#     │  │  │(Writer) │  │  (Editor)   │   │ │
#     │  │  └─────────┘  └─────────────┘   │ │
#     │  │         │            │          │ │
#     │  │         └────┬───────┘          │ │
#     │  │              │                  │ │
#     │  │         Discussion              │ │
#     │  └─────────────────────────────────┘ │
#     │                 │                    │
#     │            Synthesis                 │
#     │                 │                    │
#     │           Final Response             │
#     └─────────────────────────────────────-┘

# %%
import asyncio
from autogen_agentchat.ui import Console
from autogen_agentchat.agents import AssistantAgent, SocietyOfMindAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import TextMentionTermination
import os
from dotenv import load_dotenv
load_dotenv()

api_key = os.getenv("OPEN_ROUTER_API_KEY") 


model_client = OpenAIChatCompletionClient(
base_url="https://openrouter.ai/api/v1",
api_key=api_key,
model="qwen/qwen3-vl-30b-a3b-thinking",    
model_info={
    "family": "qwen",
    "vision": False,
    "function_calling": True,
    "json_output": True,
    "structured_output": True
    },
)
agent1 = AssistantAgent("assistant1", model_client=model_client, system_message="You are a writer, write well under 50 words.")
agent2 = AssistantAgent(
    "assistant2",
    model_client=model_client,
    system_message="You are an editor, provide critical feedback under 50 words. Respond with 'APPROVE' if the text addresses all feedbacks.",
)
inner_termination = TextMentionTermination("APPROVE")
inner_team = RoundRobinGroupChat([agent1, agent2], termination_condition=inner_termination)


society_of_mind_agent = SocietyOfMindAgent("society_of_mind", team=inner_team, model_client=model_client,response_prompt='Output a standalone response to the original request under 50 words, without mentioning any of the intermediate discussion.')

agent4 = society_of_mind_agent = SocietyOfMindAgent("society_of_mind", team=inner_team, model_client=model_client,response_prompt='Output a standalone response to the original request under 50 words, without mentioning any of the intermediate discussion.')



agent3 = AssistantAgent(
    "assistant3", model_client=model_client, system_message="Translate the text to Spanish under 50 words."
)
team = RoundRobinGroupChat([society_of_mind_agent, agent3], max_turns=2)

stream = team.run_stream(task="Write a short story with a surprising ending under 50 words.")
await Console(stream)
# Out:
# ---------- TextMessage (user) ----------
# Write a short story with a surprising ending under 50 words.
# ---------- TextMessage (assistant1) ----------
# He hid under his blanket, heart pounding. The closet door creaked open. "Boo!" whispered a voice. He froze, expecting a monster. Instead, his own voice said, "I am the monster."
# ---------- TextMessage (assistant2) ----------
# The story meets the word limit (38 words) and delivers a genuinely surprising twist. The ending effectively subverts expectations by making the "monster" internalized fear. Minor note: "his own voice" could be slightly ambiguous (physical or metaphorical?), but this ambiguity enhances the psychological horror. Overall strong execution.
#
# APPROVE
# ---------- TextMessage (society_of_mind) ----------
# The story meets all requirements: 38 words, surprising twist, and psychological horror. Approved.
# ---------- TextMessage (assistant3) ----------
# Encontré un espejo oscuro en el ático. Mostraba mi reflejo... pero sonrió cuando yo no lo hice. Luego salió. Me desperté en el espejo. Ahora veo a mí mismo fuera de mi ventana. Mis ojos están abiertos, pero no puedo moverme. (38 palabras)
# TaskResult(messages=[TextMessage(id='2c56258c-92a0-435c-9ea2-af4abcb08848', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 19, 19, 14, 52, 169894, tzinfo=datetime.timezone.utc), content='Write a short story with a surprising ending under 50 words.', type='TextMessage'), TextMessage(id='ab5b3314-03bb-4dce-9cfd-2d4c28cec9c0', source='assistant1', models_usage=RequestUsage(prompt_tokens=42, completion_tokens=380), metadata={}, created_at=datetime.datetime(2026, 2, 19, 19, 14, 56, 273705, tzinfo=datetime.timezone.utc), content='He hid under his blanket, heart pounding. The closet door creaked open. "Boo!" whispered a voice. He froze, expecting a monster. Instead, his own voice said, "I am the monster."', type='TextMessage'), TextMessage(id='d6275871-2e47-44f5-a45c-5392f686fb29', source='assistant2', models_usage=RequestUsage(prompt_tokens=103, completion_tokens=442), metadata={}, created_at=datetime.datetime(2026, 2, 19, 19, 14, 59, 755517, tzinfo=datetime.timezone.utc), content='The story meets the word limit (38 words) and delivers a genuinely surprising twist. The ending effectively subverts expectations by making the "monster" internalized fear. Minor note: "his own voice" could be slightly ambiguous (physical or metaphorical?), but this ambiguity enhances the psychological horror. Overall strong execution.  \n\nAPPROVE', type='TextMessage'), TextMessage(id='c0d5e137-597b-4fc5-a621-08112ac88981', source='society_of_mind', models_usage=RequestUsage(prompt_tokens=174, completion_tokens=322), metadata={}, created_at=datetime.datetime(2026, 2, 19, 19, 15, 2, 601552, tzinfo=datetime.timezone.utc), content='The story meets all requirements: 38 words, surprising twist, and psychological horror. Approved.', type='TextMessage'), TextMessage(id='57a1d005-6ff3-4a81-8599-d3e08f1b469d', source='assistant3', models_usage=RequestUsage(prompt_tokens=60, completion_tokens=3813), metadata={}, created_at=datetime.datetime(2026, 2, 19, 19, 15, 32, 741850, tzinfo=datetime.timezone.utc), content='Encontré un espejo oscuro en el ático. Mostraba mi reflejo... pero sonrió cuando yo no lo hice. Luego salió. Me desperté en el espejo. Ahora veo a mí mismo fuera de mi ventana. Mis ojos están abiertos, pero no puedo moverme. (38 palabras)', type='TextMessage')], stop_reason='Maximum number of turns 2 reached.')
