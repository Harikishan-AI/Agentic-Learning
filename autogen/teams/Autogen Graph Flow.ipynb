# %%
import os
from dotenv import load_dotenv
load_dotenv()

import asyncio

from codecs import StreamReader
from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.teams import SelectorGroupChat
from autogen_agentchat.conditions import TextMentionTermination, MaxMessageTermination
from autogen_agentchat.ui import Console
from autogen_agentchat.teams import DiGraphBuilder, GraphFlow

api_key = os.getenv("OPEN_ROUTER_API_KEY") 

model_client = OpenAIChatCompletionClient(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
    model="openai/gpt-4o-mini",    
    model_info={
        "family": "openai",
        "vision": False,
        "function_calling": True,
        "json_output": True,
        "structured_output": True
    },
)

# %% [markdown]
# # Sequential Flow

# %%
writer = AssistantAgent(
    name="Writer",
    description="A writer agent that generates text based on user input.",
    model_client=model_client,
    system_message="You are a creative writer. Please write a story based on the user's input.",
)

reviewer = AssistantAgent(
    name="Reviewer",
    description="A reviewer agent that provides feedback on the text generated by the writer.",
    model_client=model_client,
    system_message="You are a reviewer. Please provide feedback on the text generated by the writer.",
)

# %%
builder = DiGraphBuilder()
builder.add_node(writer).add_node(reviewer)
builder.add_edge(writer, reviewer)

graph = builder.build()

# %%
graph
# Out:
# DiGraph(nodes={'Writer': DiGraphNode(name='Writer', edges=[DiGraphEdge(target='Reviewer', condition=None, condition_function=None, activation_group='Reviewer', activation_condition='all')], activation='all'), 'Reviewer': DiGraphNode(name='Reviewer', edges=[], activation='all')}, default_start_node=None)

# %%
team = GraphFlow([writer,reviewer], graph)

# %%
stream = team.run_stream(task ="Write a good poem about India in less than 30 words.")

async for event in stream:
    print(event)
# Out:
# id='f0f3ddac-7e91-421a-9e8a-2caafae05f57' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 23, 53, 138181, tzinfo=datetime.timezone.utc) content='Write a good poem about India in less than 30 words.' type='TextMessage'
# id='b41008ff-7956-441c-b91f-32bcfb927003' source='Writer' models_usage=RequestUsage(prompt_tokens=41, completion_tokens=41) metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 23, 55, 88705, tzinfo=datetime.timezone.utc) content='Land of vibrant hues, where cultures entwine,  \nGanges whispers stories, ancient and divine.  \nMountains stand tall, with hearts so wide,  \nIn unity and pride, India abides.' type='TextMessage'
# id='f8689019-d516-43d9-b22f-92ae748dbc80' source='Reviewer' models_usage=RequestUsage(prompt_tokens=88, completion_tokens=85) metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 23, 57, 88292, tzinfo=datetime.timezone.utc) content='This poem beautifully captures the essence of India through vivid imagery and emotion. The use of "vibrant hues" effectively conveys the diversity of cultures. The imagery of the Ganges and mountains adds depth and connects nature with spirituality. The closing line emphasizes unity and pride, resonating with the overall theme. Consider varying the rhythm slightly to enhance the flow, but overall, it\'s a succinct and evocative piece. Well done!' type='TextMessage'
# messages=[TextMessage(id='f0f3ddac-7e91-421a-9e8a-2caafae05f57', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 23, 53, 138181, tzinfo=datetime.timezone.utc), content='Write a good poem about India in less than 30 words.', type='TextMessage'), TextMessage(id='b41008ff-7956-441c-b91f-32bcfb927003', source='Writer', models_usage=RequestUsage(prompt_tokens=41, completion_tokens=41), metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 23, 55, 88705, tzinfo=datetime.timezone.utc), content='Land of vibrant hues, where cultures entwine,  \nGanges whispers stories, ancient and divine.  \nMountains stand tall, with hearts so wide,  \nIn unity and pride, India abides.', type='TextMessage'), TextMessage(id='f8689019-d516-43d9-b22f-92ae748dbc80', source='Reviewer', models_usage=RequestUsage(prompt_tokens=88, completion_tokens=85), metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 23, 57, 88292, tzinfo=datetime.timezone.utc), content='This poem beautifully captures the essence of India through vivid imagery and emotion. The use of "vibrant hues" effectively conveys the diversity of cultures. The imagery of the Ganges and mountains adds depth and connects nature with spirituality. The closing line emphasizes unity and pride, resonating with the overall theme. Consider varying the rhythm slightly to enhance the flow, but overall, it\'s a succinct and evocative piece. Well done!', type='TextMessage')] stop_reason='Digraph execution is complete'

# %% [markdown]
# # Parallel Fan out

# %%
agent_a = AssistantAgent("A", model_client=model_client, system_message="You are a helpful assistant.")
agent_b = AssistantAgent("B", model_client=model_client, system_message="Translate input to Chinese.")
agent_c = AssistantAgent("C", model_client=model_client, system_message="Translate input to Japanese.")

# Create a directed graph with fan-out flow A -> (B, C).
builder = DiGraphBuilder()
builder.add_node(agent_a).add_node(agent_b).add_node(agent_c)
builder.add_edge(agent_a, agent_b).add_edge(agent_a, agent_c)
graph = builder.build()

# Create a GraphFlow team with the directed graph.
team = GraphFlow(
    participants=[agent_a, agent_b, agent_c],
    graph=graph,
    termination_condition=MaxMessageTermination(5),
)

# Run the team and print the events.
async for event in team.run_stream(task="Write a short story about a cat."):
    print(event)
# Out:
# id='2b1ff277-78ec-40c8-90bb-f0d3e52ba654' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 23, 57, 126029, tzinfo=datetime.timezone.utc) content='Write a short story about a cat.' type='TextMessage'
# id='e0ed2a7e-c1b1-4dd9-8aa5-b6a9ea13ed60' source='A' models_usage=RequestUsage(prompt_tokens=26, completion_tokens=667) metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 24, 9, 943452, tzinfo=datetime.timezone.utc) content='Once upon a time in a quaint little village, there lived a curious cat named Whiskers. Whiskers was not your ordinary feline; he was a fluffy orange tabby with bright green eyes that sparkled with mischief. Every day, he would venture out of his cozy home, a small cottage owned by a kind elderly woman named Mrs. Maple.\n\nOne sunny morning, Whiskers decided to explore beyond the familiar cobblestone streets of the village. He slinked through the narrow alleys and ventured into the vibrant meadow that bordered the village. The air was fragrant with wildflowers, and the gentle breeze carried the sounds of chirping birds and buzzing bees.\n\nAs Whiskers wandered, he stumbled upon a shimmering blue butterfly fluttering from flower to flower. Intrigued, he crouched low and began to stalk it, his heart racing with excitement. The butterfly danced gracefully in the air, teasing Whiskers as it flitted just out of reach. In the thrill of the chase, Whiskers leaped and bounded through the meadow, feeling as if he were part of a grand adventure.\n\nAfter several delightful minutes of chasing the elusive butterfly, it suddenly landed on a nearby bush. Whiskers pounced, but as he did, he tumbled headfirst into a small, hidden burrow nestled among the roots of an old tree. Dazed but unharmed, he found himself surrounded by soft grass and the faint scent of something sweet.\n\nAs he emerged from the burrow, Whiskers discovered that he was not alone. A family of rabbits was gathered nearby, their big ears perked up in surprise at the sudden appearance of the fluffy intruder. Whiskers, intrigued, sat down, his initial instinct to chase replaced by curiosity.\n\n"Hello there!" chirped a little brown rabbit named Benny, whose nose twitched nervously. "What brings you to our home, Mr. Cat?"\n\nWhiskers, realizing he had startled them, replied gently, "I was just chasing a butterfly and accidentally fell into your burrow. I didn\'t mean to disturb you."\n\nThe rabbits exchanged glances, and after a moment, Benny\'s sister, Lily, spoke up. "We\'ve never met a cat who didn’t want to chase us! Do you want to join us for a picnic instead?"\n\nWhiskers, surprised but delighted by the invitation, nodded enthusiastically. The rabbits led him to a sunny spot in the meadow where they had laid out a feast of fresh greens, carrots, and sweet, juicy berries. They chatted and laughed, sharing stories of their adventures. Whiskers found himself enchanted by their tales of hopping through fields and evading the occasional fox.\n\nAs the sun began to set, painting the sky in shades of pink and orange, Whiskers realized it was time to head home. He thanked his new friends for an unforgettable day and promised to return for another picnic soon.\n\nAs Whiskers trotted back to Mrs. Maple’s cottage, he felt a warm glow in his heart. He had not only chased a butterfly that day but had forged a friendship with the most unlikely of companions. From that day forward, the meadow became Whiskers\' second home, where he learned that sometimes, the best adventures come from unexpected friendships.' type='TextMessage'
# id='098cf816-0212-4fc8-8640-38afecc71f1b' source='B' models_usage=RequestUsage(prompt_tokens=697, completion_tokens=870) metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 24, 26, 412721, tzinfo=datetime.timezone.utc) content='从前，在一个古雅的小村庄里，住着一只好奇的小猫，名叫胡须猫。胡须猫并不是普通的猫咪；它是一只毛茸茸的橘色虎斑猫，眼睛闪烁着顽皮的绿色光芒。每天，它都会从温馨的家中探出头来，这是一栋由善良的老妇人梅普尔夫人拥有的小小茅屋。\n\n一个阳光明媚的早晨，胡须猫决定探索村庄熟悉的鹅卵石街道以外的地方。它悄悄穿过狭窄的小巷，来到了村庄边缘的生机盎然的草地。空气中弥漫着野花的芬芳，微风轻拂，带来了鸟儿的鸣唱和蜜蜂的嗡嗡声。\n\n当胡须猫四处游荡时，它偶然发现了一只在花朵间翩翩起舞的闪亮蓝色蝴蝶。出于好奇，它低下身子开始悄悄跟踪，心中充满了兴奋。蝴蝶在空中优雅地舞动，像是在戏弄胡须猫，让它无法触及。在追逐的刺激中，胡须猫欢快地蹦跃在草地上，感觉自己正置身于一场伟大的冒险之中。\n\n在追逐了几分钟难以捉住的蝴蝶后，蝴蝶突然停在附近的一丛灌木上。胡须猫猛然扑去，结果却头朝下跌进了一处藏在古老树根之间的小隐蔽洞穴。虽然有些晕眩，但并没有受伤，它发现自己被柔软的草地包围，隐约飘来一股甜美的气息。\n\n当它从洞穴中出来时，胡须猫发现自己并不孤单。一家兔子围在附近，大大的耳朵因为这位蓬松的入侵者突然出现而惊讶地竖了起来。胡须猫满怀好奇地坐下，最初想要追逐的本能被新奇所取代。\n\n“你好啊！”一只名叫贝尼的小棕兔子用颤抖的鼻子说，“你是怎么到我们这里来的，猫先生？”\n\n胡须猫意识到自己吓到了他们，温柔地回复道：“我只是在追逐一只蝴蝶，不小心掉进了你们的窝里。我并不想打扰你们。”\n\n兔子们互相交换了眼神，过了一会儿，贝尼的妹妹莉莉开口说：“我们从未见过不想追逐我们的猫！你想不想和我们一起去野餐呢？”\n\n胡须猫惊讶但又高兴地点头同意。兔子们带着它来到草地上的一个阳光明媚的地方，那里摆满了新鲜的绿叶、胡萝卜和甜美多汁的莓果。他们一边闲聊一边欢笑，分享着各自的冒险故事。胡须猫被他们跳跃在田野间、躲避偶尔出现的狐狸的故事深深吸引。\n\n随着太阳渐渐落下，天空染上粉色和橙色，胡须猫意识到是时候回家了。它感谢新朋友们带来的难忘日子，并保证不久后再来参加野餐。\n\n当胡须猫朝着梅普尔夫人的小屋慢慢走去时，心里感到一阵温暖的幸福。今天它不仅追逐了一只蝴蝶，还与最不可能的伙伴建立了友谊。从那以后，草地成为了胡须猫的第二个家，它在这里学会了有时最好的冒险来自意想不到的友谊。' type='TextMessage'
# id='56a7c10c-3b2c-484a-bf06-413ba317d078' source='C' models_usage=RequestUsage(prompt_tokens=697, completion_tokens=1093) metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 24, 29, 441626, tzinfo=datetime.timezone.utc) content='昔々、こぢんまりとした村に、ウィスカーズという好奇心旺盛な猫が住んでいました。ウィスカーズは普通の猫ではなく、ふわふわのオレンジ色のタビーで、いたずら心を宿した輝く緑色の目を持っていました。毎日、彼は優しい老婦人のメープルさんが住む小さなコテージから出て、村のゴツゴツした石畳の道を冒険していました。\n\nある晴れた朝、ウィスカーズは、なじみのある村の道路を越えて探検することに決めました。彼は狭い路地をくぐり抜け、村の境界に広がる色とりどりの草原に足を踏み入れました。空気は野花の香りで満ち、穏やかな風が鳥のさえずりや蜂の羽音を運んでいました。\n\nウィスカーズは歩き回っていると、花から花へ舞う青い蝶々に出会いました。興味をそそられた彼は、体を低くし、心臓が興奮で高鳴るのを感じながら、それを追いかけ始めました。蝶々は空中で優雅に踊り、ウィスカーズを試すかのように、手の届かないところでひらひらと舞いました。追いかけるスリルに心を奪われたウィスカーズは、草原を跳ね回り、大冒険の一部であるかのように感じていました。\n\n数分間、逃げ回る蝶々を追った後、突然近くの茂みに止まりました。ウィスカーズは跳びかかりましたが、その瞬間、古い木の根元に隠れた小さな穴に頭から転げ込んでしまいました。ぼんやりとした状態でしたが無事だった彼は、柔らかな草に囲まれ、ほのかに甘い香りを感じました。\n\n穴から出ると、ウィスカーズは一人ではないことに気づきました。近くにはウサギの家族が集まっていて、彼らの大きな耳は驚きでぴんと立っていました。ウィスカーズは興味をそそられ、追いかける本能が好奇心に変わり、ふんぞり返って座りました。\n\n「こんにちは！」と、小さな茶色のウサギ、ベニーが鼻をぴくぴくさせながら言いました。「何の用で私たちの家に来たの、猫さん？」\n\nウィスカーズは彼らを驚かせてしまったことに気づき、優しく答えました。「蝶々を追いかけていて、誤ってあなたたちの穴に落ちてしまったんです。邪魔をするつもりはありませんでした。」\n\nウサギたちは互いに目を合わせ、しばらくしてから、ベニーの妹、リリーが口を開きました。「私たちは、私たちを追いかけたいと思わない猫に会ったことがありません！代わりにピクニックに参加しませんか？」\n\nウィスカーズは驚きながらも招待に喜んで応え、元気に頷きました。ウサギたちは、草原の太陽の当たる場所へ彼を連れて行き、新鮮な野菜、ニンジン、甘くてジューシーなベリーのごちそうを広げていました。彼らは沢山の話で笑い合い、自分たちの冒険の物語を共有しました。ウィスカーズは、彼らの野原を飛び回ることや、たまに出会うキツネから逃げる話に魅了されました。\n\n日が沈み始め、空がピンクやオレンジに染まる頃、ウィスカーズは帰る時間だと感じました。彼は新しい友達に忘れられない一日をありがとうと言い、またピクニックに行くと約束しました。\n\nウィスカーズがメープルさんのコテージへ戻る途中、心が温かくなりました。その日は蝶々を追いかけるだけでなく、最も意外な仲間たちとの友情を築くことができたのです。それ以降、草原はウィスカーズの第二の家となり、時には意外な友情から最高の冒険が生まれることを学びました。' type='TextMessage'
# messages=[TextMessage(id='2b1ff277-78ec-40c8-90bb-f0d3e52ba654', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 23, 57, 126029, tzinfo=datetime.timezone.utc), content='Write a short story about a cat.', type='TextMessage'), TextMessage(id='e0ed2a7e-c1b1-4dd9-8aa5-b6a9ea13ed60', source='A', models_usage=RequestUsage(prompt_tokens=26, completion_tokens=667), metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 24, 9, 943452, tzinfo=datetime.timezone.utc), content='Once upon a time in a quaint little village, there lived a curious cat named Whiskers. Whiskers was not your ordinary feline; he was a fluffy orange tabby with bright green eyes that sparkled with mischief. Every day, he would venture out of his cozy home, a small cottage owned by a kind elderly woman named Mrs. Maple.\n\nOne sunny morning, Whiskers decided to explore beyond the familiar cobblestone streets of the village. He slinked through the narrow alleys and ventured into the vibrant meadow that bordered the village. The air was fragrant with wildflowers, and the gentle breeze carried the sounds of chirping birds and buzzing bees.\n\nAs Whiskers wandered, he stumbled upon a shimmering blue butterfly fluttering from flower to flower. Intrigued, he crouched low and began to stalk it, his heart racing with excitement. The butterfly danced gracefully in the air, teasing Whiskers as it flitted just out of reach. In the thrill of the chase, Whiskers leaped and bounded through the meadow, feeling as if he were part of a grand adventure.\n\nAfter several delightful minutes of chasing the elusive butterfly, it suddenly landed on a nearby bush. Whiskers pounced, but as he did, he tumbled headfirst into a small, hidden burrow nestled among the roots of an old tree. Dazed but unharmed, he found himself surrounded by soft grass and the faint scent of something sweet.\n\nAs he emerged from the burrow, Whiskers discovered that he was not alone. A family of rabbits was gathered nearby, their big ears perked up in surprise at the sudden appearance of the fluffy intruder. Whiskers, intrigued, sat down, his initial instinct to chase replaced by curiosity.\n\n"Hello there!" chirped a little brown rabbit named Benny, whose nose twitched nervously. "What brings you to our home, Mr. Cat?"\n\nWhiskers, realizing he had startled them, replied gently, "I was just chasing a butterfly and accidentally fell into your burrow. I didn\'t mean to disturb you."\n\nThe rabbits exchanged glances, and after a moment, Benny\'s sister, Lily, spoke up. "We\'ve never met a cat who didn’t want to chase us! Do you want to join us for a picnic instead?"\n\nWhiskers, surprised but delighted by the invitation, nodded enthusiastically. The rabbits led him to a sunny spot in the meadow where they had laid out a feast of fresh greens, carrots, and sweet, juicy berries. They chatted and laughed, sharing stories of their adventures. Whiskers found himself enchanted by their tales of hopping through fields and evading the occasional fox.\n\nAs the sun began to set, painting the sky in shades of pink and orange, Whiskers realized it was time to head home. He thanked his new friends for an unforgettable day and promised to return for another picnic soon.\n\nAs Whiskers trotted back to Mrs. Maple’s cottage, he felt a warm glow in his heart. He had not only chased a butterfly that day but had forged a friendship with the most unlikely of companions. From that day forward, the meadow became Whiskers\' second home, where he learned that sometimes, the best adventures come from unexpected friendships.', type='TextMessage'), TextMessage(id='098cf816-0212-4fc8-8640-38afecc71f1b', source='B', models_usage=RequestUsage(prompt_tokens=697, completion_tokens=870), metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 24, 26, 412721, tzinfo=datetime.timezone.utc), content='从前，在一个古雅的小村庄里，住着一只好奇的小猫，名叫胡须猫。胡须猫并不是普通的猫咪；它是一只毛茸茸的橘色虎斑猫，眼睛闪烁着顽皮的绿色光芒。每天，它都会从温馨的家中探出头来，这是一栋由善良的老妇人梅普尔夫人 ...

# %% [markdown]
# # Cindtional Branching (A->B ("yes"), A->C (otherwise))

# %%
agent_a = AssistantAgent(
        "A",
        model_client=model_client,
        system_message="Detect if the input is in Chinese. If it is, say 'yes', else say 'no', and nothing else.",
    )
agent_b = AssistantAgent("B", model_client=model_client, system_message="Translate input to English.")
agent_c = AssistantAgent("C", model_client=model_client, system_message="Translate input to Chinese.")

# Create a directed graph with conditional branching flow A -> B ("yes"), A -> C (otherwise).
builder = DiGraphBuilder()
builder.add_node(agent_a).add_node(agent_b).add_node(agent_c)
# Create conditions as callables that check the message content.
builder.add_edge(agent_a, agent_b, condition=lambda msg: "yes" in msg.to_model_text())
builder.add_edge(agent_a, agent_c, condition=lambda msg: "yes" not in msg.to_model_text())
graph = builder.build()

# Create a GraphFlow team with the directed graph.
team = GraphFlow(
    participants=[agent_a, agent_b, agent_c],
    graph=graph,
    termination_condition=MaxMessageTermination(5),
)

# Run the team and print the events.
async for event in team.run_stream(task="AutoGen is a framework for building AI agents."):
    print(event)
# Out:
# id='a9fe2a60-4f05-489c-ba14-90544ca2d64e' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 26, 40, 138258, tzinfo=datetime.timezone.utc) content='AutoGen is a framework for building AI agents.' type='TextMessage'
# id='df4ffc72-b84a-4fe6-b2c9-7f3ed96554c8' source='A' models_usage=RequestUsage(prompt_tokens=47, completion_tokens=1) metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 26, 41, 448551, tzinfo=datetime.timezone.utc) content='no' type='TextMessage'
# id='abc41be8-ecf9-474a-8a4e-a9f7724f2c8b' source='C' models_usage=RequestUsage(prompt_tokens=33, completion_tokens=12) metadata={} created_at=datetime.datetime(2026, 2, 15, 17, 26, 42, 155815, tzinfo=datetime.timezone.utc) content='AutoGen是一个构建AI代理的框架。' type='TextMessage'
# messages=[TextMessage(id='a9fe2a60-4f05-489c-ba14-90544ca2d64e', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 26, 40, 138258, tzinfo=datetime.timezone.utc), content='AutoGen is a framework for building AI agents.', type='TextMessage'), TextMessage(id='df4ffc72-b84a-4fe6-b2c9-7f3ed96554c8', source='A', models_usage=RequestUsage(prompt_tokens=47, completion_tokens=1), metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 26, 41, 448551, tzinfo=datetime.timezone.utc), content='no', type='TextMessage'), TextMessage(id='abc41be8-ecf9-474a-8a4e-a9f7724f2c8b', source='C', models_usage=RequestUsage(prompt_tokens=33, completion_tokens=12), metadata={}, created_at=datetime.datetime(2026, 2, 15, 17, 26, 42, 155815, tzinfo=datetime.timezone.utc), content='AutoGen是一个构建AI代理的框架。', type='TextMessage')] stop_reason='Digraph execution is complete'
